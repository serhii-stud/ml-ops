# %%
import os
os.chdir('/home/sagemaker-user/ml-ops/lab3')
os.listdir()
# Out:
# ['.env-sample',
#  '.gitignore',
#  'Dockerfile',
#  'Dockerfile.airflow',
#  'Dockerfile.mlflow',
#  'Dockerfile.ms',
#  'Dockerfile.train',
#  'README.md',
#  'dags',
#  'data',
#  'docker-compose.yaml',
#  'requirements-airflow.txt',
#  'requirements.txt',
#  'scripts',
#  'src',
#  'sm']

# %%
# noqa: E402
from src.sm.processing.data_prep import build_training_dataset

dv = build_training_dataset(data_version="debug")
dv
# Out:
# >>> DATA VERSION: debug
# >>> Loading logs from: s3://mlops-project-sm/data/logs/inference/*.jsonl
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.12/site-packages/fsspec/core.py:105, in OpenFile.__enter__(self)
#     104 try:
# --> 105     f = self.fs.open(self.path, mode=mode)
#     106 except FileNotFoundError as e:
#
# File /opt/conda/lib/python3.12/site-packages/fsspec/spec.py:1310, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1309 ac = kwargs.pop("autocommit", not self._intrans)
# -> 1310 f = self._open(
#    1311     path,
#    1312     mode=mode,
#    1313     block_size=block_size,
#    1314     autocommit=ac,
#    1315     cache_options=cache_options,
#    1316     **kwargs,
#    1317 )
#    1318 if compression is not None:
#
# ...
